# %% [markdown]
# import cac thu vien va load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pymongo import MongoClient
import numpy as np
import seaborn as sns

df=pd.read_csv('./laptopData.csv')

df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 12 columns]

# %% [markdown]
# xem xet cac row co it nhat 1 gia tri null

# %%
null_row=df.isnull()

null_row=df[null_row.any(axis=1)]

null_row
# Out:
#       Unnamed: 0 Company TypeName Inches ScreenResolution  Cpu  Ram Memory  \
# 20           NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 46           NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 50           NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 115          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 125          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 148          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 190          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 209          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 267          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 336          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 350          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 478          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 567          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 616          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 625          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 629          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 666          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 699          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 726          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 747          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 753          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 774          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 922          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 923          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 938          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 978          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 994          NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 1060         NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 1202         NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
# 1245         NaN     NaN      NaN    NaN              NaN  NaN  NaN    NaN
#
#       Gpu OpSys Weight  Price
# 20    NaN   NaN    NaN    NaN
# 46    NaN   NaN    NaN    NaN
# 50    NaN   NaN    NaN    NaN
# 115   NaN   NaN    NaN    NaN
# 125   NaN   NaN    NaN    NaN
# 148   NaN   NaN    NaN    NaN
# 190   NaN   NaN    NaN    NaN
# 209   NaN   NaN    NaN    NaN
# 267   NaN   NaN    NaN    NaN
# 336   NaN   NaN    NaN    NaN
# 350   NaN   NaN    NaN    NaN
# 478   NaN   NaN    NaN    NaN
# 567   NaN   NaN    NaN    NaN
# 616   NaN   NaN    NaN    NaN
# 625   NaN   NaN    NaN    NaN
# 629   NaN   NaN    NaN    NaN
# 666   NaN   NaN    NaN    NaN
# 699   NaN   NaN    NaN    NaN
# 726   NaN   NaN    NaN    NaN
# 747   NaN   NaN    NaN    NaN
# 753   NaN   NaN    NaN    NaN
# 774   NaN   NaN    NaN    NaN
# 922   NaN   NaN    NaN    NaN
# 923   NaN   NaN    NaN    NaN
# 938   NaN   NaN    NaN    NaN
# 978   NaN   NaN    NaN    NaN
# 994   NaN   NaN    NaN    NaN
# 1060  NaN   NaN    NaN    NaN
# 1202  NaN   NaN    NaN    NaN
# 1245  NaN   NaN    NaN    NaN

# %% [markdown]
# Ta co the thay cac ban ghi co rat nhieu gia tri null nen ta se xoa het cac row co it nhat 1 gia tri null.

# %%
df=df.dropna() # loai bo cac ban ghi co it nhat 1 cot la null

df # hien thi data
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1273 rows x 12 columns]

# %% [markdown]
# Ta se drop truong Unname: 0 vi no chinh la truong STT

# %%
print(df.columns)
df.drop('Unnamed: 0', axis=1, inplace=True)
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')
# /tmp/ipykernel_526874/2013936524.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# Clean truong Inches

# %% [markdown]
# Xem xet cac gia tri trong truong Inches va ve bieu do de quan sat de hon

# %%
# Tim cac gia tri doc nhat xuat hien trong truong Inches
unique_value=set(df['Inches']) # Dung set de loc cac gia tri trung

# In ra man hinh cac gia tri
print(unique_value)
# Out:
# {'?', '27.3', '35.6', '11.3', '18.4', '14', '14.1', '12.3', '31.6', '13.9', '25.6', '33.5', '24', '11.6', '10.1', '15.6', '13.3', '15', '13', '15.4', '12', '17.3', '17', '13.5', '12.5'}

# %% [markdown]
# Ta co the thay truong Inches co ca gia tri khong hop le nhu '?' va cac outlier.

# %% [markdown]
# Loai bo cac gia tri khong hop le va chuyen truong Inches sang dang so

# %%
# chuyen cac gia tri trong truong Inches thanh so, neu khong chuyen duoc thi se chuyen thanh null
df.loc[:,'Inches']=pd.to_numeric(df['Inches'], errors='coerce')

# quan sat cac ban ghi bi null
all_null_row=df[df.isnull().any(axis=1)]
all_null_row
# Out:
#     Company     TypeName Inches   ScreenResolution  \
# 476    Dell  Workstation    NaN  Full HD 1920x1080
#
#                              Cpu  Ram     Memory                  Gpu  \
# 476  Intel Core i7 7700HQ 2.8GHz  8GB  256GB SSD  Nvidia Quadro M1200
#
#           OpSys  Weight      Price
# 476  Windows 10  1.78kg  128298.24

# %%
# Gen gia tri inches theo 5 gia tri co tan so cao nhat
top5_inches=df['Inches'].value_counts().index[:5].to_list()
# dien tat cac cac gia tri null trong truong inches bang cach chon ngay nhien 1 trong 5 
df.loc[:,'Inches']=df['Inches'].apply(lambda x: np.random.choice(top5_inches) if pd.isnull(x) else x)
# kiem tra xem trong tuong inches con gia tri null nao khong neu khong thi tra ve false
print(df['Inches'].isnull().any())
# Out:
# False

# %% [markdown]
# Ve bieu do cho truong inches de de quan sat du lieu

# %%
# ve bieu do cot 
plt.figure(figsize=(10,6))
plt.hist(df['Inches'], bins=20, color='skyblue', edgecolor= 'black')
plt.xlabel('Inches')
plt.ylabel('Frequency')
plt.title('Bieu do cot theo Inches')
plt.show()

#Ve bieu do tron
all_value=df['Inches'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(all_value, labels=all_value.index, autopct='%1.1f%%', startangle=140)
plt.title('Bieu do tron cho truong Inches')
plt.show()

# %% [markdown]
# Su dung IQR de loai bo outlier

# %%
Q1=df['Inches'].quantile(0.25)
Q3=df['Inches'].quantile(0.75)
IQR= Q3-Q1
# tim ra cac muc voi IQR
lower_bound=Q1 - 1.5*IQR
upper_bound= Q3 + 1.5*IQR

df.loc[:,'Inches']=df['Inches'].where((df['Inches']>=lower_bound) & (df['Inches']<=upper_bound))

all_null_row=df[df.isnull().any(axis=1)]
all_null_row
# print('len =',len(all_null_row))
# Out:
#         Company            TypeName Inches  \
# 177         MSI              Gaming    NaN
# 314        Asus  2 in 1 Convertible    NaN
# 319        Acer            Notebook    NaN
# 348        Asus  2 in 1 Convertible    NaN
# 376      Lenovo             Netbook    NaN
# 402      Lenovo            Notebook    NaN
# 408      Lenovo            Notebook    NaN
# 409      Lenovo            Notebook    NaN
# 423        Asus            Notebook    NaN
# 424        Dell              Gaming    NaN
# 429    Mediacom  2 in 1 Convertible    NaN
# 430     Samsung             Netbook    NaN
# 438      Lenovo           Ultrabook    NaN
# 455        Dell  2 in 1 Convertible    NaN
# 458   Microsoft           Ultrabook    NaN
# 461        Acer             Netbook    NaN
# 500        Asus             Netbook    NaN
# 504      Lenovo             Netbook    NaN
# 515        Asus             Netbook    NaN
# 525      Lenovo            Notebook    NaN
# 560        Acer  2 in 1 Convertible    NaN
# 584        Dell             Netbook    NaN
# 592        Dell  2 in 1 Convertible    NaN
# 619        Acer  2 in 1 Convertible    NaN
# 673      Lenovo            Notebook    NaN
# 677          HP  2 in 1 Convertible    NaN
# 695        Acer             Netbook    NaN
# 750      Lenovo             Netbook    NaN
# 804        Dell             Netbook    NaN
# 817          HP             Netbook    NaN
# 828        Acer             Netbook    NaN
# 846          HP  2 in 1 Convertible    NaN
# 888        Acer             Netbook    NaN
# 944      Lenovo  2 in 1 Convertible    NaN
# 957          HP  2 in 1 Convertible    NaN
# 959        Acer  2 in 1 Convertible    NaN
# 1049       Asus             Netbook    NaN
# 1082     Lenovo  2 in 1 Convertible    NaN
# 1114     Lenovo  2 in 1 Convertible    NaN
# 1126     Lenovo  2 in 1 Convertible    NaN
# 1215       Acer             Netbook    NaN
# 1234      Apple           Ultrabook    NaN
# 1268         HP             Netbook    NaN
# 1282         HP             Netbook    NaN
# 1296         HP             Netbook    NaN
#
#                                ScreenResolution  \
# 177                           Full HD 1920x1080
# 314                        Touchscreen 1366x768
# 319                                    1366x768
# 348                        Touchscreen 1366x768
# 376                          IPS Panel 1366x768
# 402                 IPS Panel Full HD 1920x1080
# 408                           Full HD 1920x1080
# 409                                    1366x768
# 423                           Full HD 1920x1080
# 424                         IPS Panel 2560x1440
# 429   IPS Panel Full HD / Touchscreen 1920x1080
# 430                                    1366x768
# 438                                   2560x1440
# 455                        Touchscreen 1366x768
# 458                       Touchscreen 2256x1504
# 461                                    1366x768
# 500                                    1366x768
# 504                                    1366x768
# 515                                    1366x768
# 525                           Full HD 1920x1080
# 560   IPS Panel Full HD / Touchscreen 1920x1080
# 584                                    1366x768
# 592                        Touchscreen 1366x768
# 619              IPS Panel Touchscreen 1366x768
# 673                                    1366x768
# 677                        Touchscreen 1366x768
# 695                                    1366x768
# 750                        Touchscreen 1366x768
# 804                                    1366x768
# 817                                    1366x768
# 828                          IPS Panel 1366x768
# 846                        Touchscreen 1366x768
# 888                          IPS Panel 1366x768
# 944   IPS Panel Full HD / Touchscreen 1920x1080
# 957                        Touchscreen 1366x768
# 959              IPS Panel Touchscreen 1366x768
# 1049                                   1366x768
# 1082            IPS Panel Touchscreen 1920x1200
# 1114            IPS Panel Touchscreen 1920x1200
# 1126            IPS Panel Touchscreen 1920x1200
# 1215                                   1366x768
# 1234                                   1366x768
# 1268                                   1366x768
# 1282                                   1366x768
# 1296                                   1366x768
#
#                                        Cpu   Ram                Memory  \
# 177            Intel Core i7 6920HQ 2.9GHz  32GB  512GB SSD +  1TB HDD
# 314   Intel Celeron Dual Core N3350 1.1GHz   2GB    32GB Flash Storage
# 319   Intel Pentium Quad Core N3710 1.6GHz   4GB   128GB Flash Storage
# 348   Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 376   Intel Celeron Quad Core N3450 1.1GHz   4GB             128GB SSD
# 402             Intel Core i5 8250U 1.6GHz   8GB  256GB SSD +  1TB HDD
# 408               Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 409   Intel Celeron Dual Core N3350 1.1GHz   2GB    32GB Flash Storage
# 423             Intel Core i3 7100U 2.4GHz   8GB               1TB HDD
# 424            Intel Core i7 7820HK 2.9GHz  16GB  256GB SSD +  1TB HDD
# 429   Intel Celeron Dual Core N3350 1.1GHz   4GB              32GB SSD
# 430   Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 438             Intel Core i7 7500U 2.7GHz  24GB             512GB SSD
# 455   Intel Pentium Quad Core N3710 1.6GHz   4GB             500GB HDD
# 458             Intel Core i7 7660U 2.5GHz   8GB             256GB SSD
# 461   Intel Celeron Dual Core N3060 1.6GHz   4GB             128GB SSD
# 500   Intel Celeron Dual Core N3350 1.1GHz   4GB    64GB Flash Storage
# 504   Intel Celeron Dual Core N3060 1.6GHz   4GB              16GB SSD
# 515   Intel Celeron Dual Core N3350 1.1GHz   2GB    32GB Flash Storage
# 525             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 560   Intel Celeron Dual Core N3350 2.0GHz   4GB    32GB Flash Storage
# 584   Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 592               Intel Core M 7Y30 1.0GHz   4GB             128GB SSD
# 619   Intel Celeron Quad Core N3160 1.6GHz   4GB    32GB Flash Storage
# 673            AMD E-Series E2-9000 2.2GHz   4GB             128GB SSD
# 677   Intel Celeron Dual Core N3350 1.1GHz   8GB    64GB Flash Storage
# 695   Intel Celeron Dual Core N3050 1.6GHz   4GB    32GB Flash Storage
# 750   Intel Celeron Dual Core N3060 1.6GHz   4GB             128GB SSD
# 804   Intel Pentium Quad Core N4200 1.1GHz   4GB             128GB SSD
# 817   Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 828   Intel Celeron Dual Core N3060 1.6GHz   4GB    32GB Flash Storage
# 846   Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 888   Intel Celeron Dual Core N3060 1.6GHz   4GB    32GB Flash Storage
# 944            Intel Core M m7-6Y75 1.2GHz   8GB             256GB SSD
# 957   Intel Pentium Quad Core N4200 1.1GHz   4GB             256GB SSD
# 959   Intel Celeron Dual Core N3060 1.6GHz   4GB    32GB Flash Storage
# 1049  Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 1082           Intel Atom x5-Z8550 1.44GHz   4GB    64GB Flash Storage
# 1114           Intel Atom x5-Z8550 1.44GHz   4GB    64GB Flash Storage
# 1126           Intel Atom x5-Z8550 1.44GHz   4GB    64GB Flash Storage
# 1215  Intel Celeron Dual Core 3205U 1.5GHz   2GB              32GB SSD
# 1234                  Intel Core i5 1.6GHz   4GB   256GB Flash Storage
# 1268  Intel Celeron Dual Core N3060 1.6GHz   2GB    32GB Flash Storage
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB    32GB Flash Storage
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB    32GB Flash Storage
#
#                                Gpu         OpSys  Weight        Price
# 177             Nvidia GTX 980 SLI    Windows 10   4.4kg  149130.7200
# 314          Intel HD Graphics 500    Windows 10   1.1kg   14652.0000
# 319          Intel HD Graphics 405    Windows 10   1.4kg   25840.8000
# 348          Intel HD Graphics 500    Windows 10   1.5kg   19980.0000
# 376          Intel HD Graphics 500    Windows 10  1.59kg   29463.8400
# 402              AMD Radeon RX 550    Windows 10   2.1kg   60978.9600
# 408          Intel HD Graphics 520    Windows 10   2.2kg   21791.5200
# 409          Intel HD Graphics 500    Windows 10  1.15kg   16221.0960
# 423           Nvidia GeForce 940MX         Linux   2.3kg   31808.1600
# 424        Nvidia GeForce GTX 1070    Windows 10  4.42kg  149130.7200
# 429          Intel HD Graphics 500    Windows 10  1.16kg   15930.7200
# 430          Intel HD Graphics 400     Chrome OS  1.15kg   14332.3200
# 438          Intel HD Graphics 620    Windows 10  1.32kg  126912.9600
# 455          Intel HD Graphics 405    Windows 10  1.47kg   25521.1200
# 458   Intel Iris Plus Graphics 640  Windows 10 S  1.25kg   95850.7200
# 461          Intel HD Graphics 400    Windows 10   1.4kg   23176.8000
# 500          Intel HD Graphics 500  Windows 10 S   1.2kg   18115.2000
# 504          Intel HD Graphics 400     Chrome OS  1.25kg   14119.2000
# 515          Intel HD Graphics 500    Windows 10   1.1kg   13053.6000
# 525          Intel HD Graphics 520     Windows 7  2.02kg   71395.2000
# 560          Intel HD Graphics 500    Windows 10  1.25kg   18594.7200
# 584          Intel HD Graphics 400     Chrome OS  1.26kg   15717.6000
# 592          Intel HD Graphics 615    Windows 10  1.39kg   32127.8400
# 619          Intel HD Graphics 400     Chrome OS  1.25kg   20193.1200
# 673         AMD Radeon R2 Graphics    Windows 10   2.2kg   18594.7200
# 677          Intel HD Graphics 500     Chrome OS   1.4kg   26373.6000
# 695              Intel HD Graphics    Windows 10   1.4kg   14332.3200
# 750          Intel HD Graphics 400    Windows 10   1.4kg   25308.0000
# 804          Intel HD Graphics 505    Windows 10  1.63kg   39640.3200
# 817          Intel HD Graphics 400     Chrome OS  1.23kg   20512.8000
# 828          Intel HD Graphics 400     Chrome OS  1.35kg   18914.4000
# 846          Intel HD Graphics 500     Chrome OS   1.4kg   32767.2000
# 888          Intel HD Graphics 400     Chrome OS  1.25kg   15824.1600
# 944          Intel HD Graphics 515    Windows 10   1.1kg   69210.7200
# 957          Intel HD Graphics 505    Windows 10  1.45kg   41292.0000
# 959          Intel HD Graphics 400     Chrome OS  1.25kg   20725.9200
# 1049         Intel HD Graphics 400     Chrome OS   1.2kg   15339.3120
# 1082         Intel HD Graphics 400    Windows 10  0.69kg   34433.2656
# 1114         Intel HD Graphics 400       Android  0.69kg   29250.7200
# 1126         Intel HD Graphics 400    Windows 10  0.69kg   25521.1200
# 1215             Intel HD Graphics     Chrome OS   1.3kg    9270.7200
# 1234        Intel HD Graphics 6000      Mac OS X  1.08kg   51095.5200
# 1268         Intel HD Graphics 400    Windows 10  1.17kg   11135.5200
# 1282         Intel HD Graphics 400    Windows 10  1.17kg   11135.5200
# 1296         Intel HD Graphics 400    Windows 10  1.17kg   11135.5200

# %% [markdown]
# Generate cac gia tri cho cac outlier

# %%
top5_inches=df['Inches'].value_counts().nlargest(5) # 5 gia tri pho bien nhat

prob=top5_inches/top5_inches.sum() # tinh xac xuat cho tung gia tri

# chon cac gia tri theo phan phoi da cho truoc
df.loc[:,'Inches']=df['Inches'].apply(lambda x: np.random.choice(top5_inches.index, p=prob) if pd.isnull(x) else x)

# ve bieu do cot 
plt.figure(figsize=(10,6))
plt.hist(df['Inches'], bins=20, color='skyblue', edgecolor= 'black')
plt.xlabel('Inches')
plt.ylabel('Frequency')
plt.title('Bieu do cot theo Inches')
plt.show()

#Ve bieu do tron
all_value=df['Inches'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(all_value, labels=all_value.index, autopct='%1.1f%%', startangle=140)
plt.title('Bieu do tron cho truong Inches')
plt.show()

# %% [markdown]
# Kiem tra cac ban ghi khong phai la so

# %%
# Lọc các bản ghi không phải số
non_numeric_records = df[~df['Inches'].apply(lambda x: isinstance(x, (int, float)))]

# In các bản ghi không phải số
print(non_numeric_records)
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %% [markdown]
# Clean truong ScreenResolution

# %% [markdown]
# Co hai thu rat quan trong cua mot cai man hinh trong dataset nay la do phan giai man hinh va tam nen

# %% [markdown]
# Kiem tra xem truong ScreenResolution co cac tam nem man hinh gi

# %%
# Kiem tra xem trong data co cac loai ma hinh gi (khong phan biet hoa, thuong)
oled=df[df['ScreenResolution'].str.contains('oled', case=False, na=False)]
print('oled  len=',len(oled))
print(oled)
# Tam nen IPS
ips=df[df['ScreenResolution'].str.contains('ips', case=False, na=False)]
print('ips  len=', len(ips))
print(ips)
# Tam nen TN
tn=df[df['ScreenResolution'].str.contains('tn', case=False, na=False)]
print('tn len=', len(tn))
print(tn)
# Out:
# oled  len= 0
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []
# ips  len= 359
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# 6      Apple           Ultrabook   15.4
# 9       Acer           Ultrabook   14.0
# ...      ...                 ...    ...
# 1285  Lenovo  2 in 1 Convertible   13.3
# 1289    Asus           Ultrabook   13.3
# 1293  Lenovo            Notebook   15.6
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
#
#                                 ScreenResolution                          Cpu  \
# 0             IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 3             IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# 4             IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz
# 6             IPS Panel Retina Display 2880x1800         Intel Core i7 2.2GHz
# 9                    IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# ...                                          ...                          ...
# 1285  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6500U 2.5GHz
# 1289                 IPS Panel Full HD 1920x1080     Intel Core M 6Y30 0.9GHz
# 1293                 IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 1298   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6500U 2.5GHz
#
#        Ram               Memory                           Gpu       OpSys  \
# 0      8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 3     16GB            512GB SSD            AMD Radeon Pro 455       macOS
# 4      8GB            256GB SSD  Intel Iris Plus Graphics 650       macOS
# 6     16GB  256GB Flash Storage       Intel Iris Pro Graphics    Mac OS X
# 9      8GB            256GB SSD        Intel UHD Graphics 620  Windows 10
# ...    ...                  ...                           ...         ...
# 1285  16GB            512GB SSD         Intel HD Graphics 520  Windows 10
# 1289   8GB            512GB SSD         Intel HD Graphics 515  Windows 10
# 1293   8GB              1TB HDD       Nvidia GeForce GTX 960M  Windows 10
# 1298   4GB            128GB SSD         Intel HD Graphics 520  Windows 10
# 1299  16GB            512GB SSD         Intel HD Graphics 520  Windows 10
#
#       Weight        Price
# 0     1.37kg   71378.6832
# 3     1.83kg  135195.3360
# 4     1.37kg   96095.8080
# 6     2.04kg  114017.6016
# 9      1.6kg   41025.6000
# ...      ...          ...
# 1285   1.3kg   79866.7200
# 1289   1.2kg   38841.1200
# 1293   2.6kg   47898.7200
# 1298   1.8kg   33992.6400
# 1299   1.3kg   79866.7200
#
# [359 rows x 11 columns]
# tn len= 0
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %% [markdown]
# Ta nhan thay chi co tam nen IPS duoc liet ke trong dataset nay

# %% [markdown]
# Lay do phan gia man hinh tu data

# %%
# loai lay do phan giai man hinh bang regex
df['Resolution']=df['ScreenResolution'].str.extract(r'(\d{3,4}+x+\d{3,4})')
# in data
df
# Out:
# /tmp/ipykernel_526874/2565980510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Resolution']=df['ScreenResolution'].str.extract(r'(\d{3,4}+x+\d{3,4})')
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible   14.0
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   14.0
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price Resolution
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832  2560x1600
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232   1440x900
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000  1920x1080
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360  2880x1800
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080  2560x1600
# ...                            ...         ...     ...          ...        ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400  1920x1080
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200  3200x1800
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200   1366x768
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200   1366x768
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200   1366x768
#
# [1273 rows x 12 columns]

# %% [markdown]
# tao cac cot dummy_value de phan loai do phan giai man hinh, cung nhu tam nen

# %%
# tao cot dummy_res de phan loai do phan giai
df['dummy_res']=df['Resolution'].apply(lambda x: 1 if x[0]=='1' else
                                                2 if x[0]=='2' else
                                                3 if x[0]=='3' else np.nan())
# kiem tra xem co ban ghi nao khong the chuyen thanh dummy value duoc khong
is_null=df['dummy_res'].isnull().any() 
is_null # ta thay tat ca deu tot
# Out:
# /tmp/ipykernel_526874/2155207401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dummy_res']=df['Resolution'].apply(lambda x: 1 if x[0]=='1' else
# np.False_

# %% [markdown]
# Ve bieu do de the hien do phan giai man hinh

# %%
# Ve bieu do tron
plt.figure(figsize=(6,6))
plt.pie(df['dummy_res'].value_counts().values, labels=df['dummy_res'].value_counts().index, autopct='%1.1f%%', startangle=124)
plt.title('Bieu do the hien phan bo cua dummy_res')
plt.show()

# %% [markdown]
# Tao cot dummy_panel cho man hinh IPS

# %%
# neu la man hinh IPS thi dummy_panel se la 1 nguoc lai la 0
df['dummy_panel']=df['ScreenResolution'].str.contains('ips', case=False, na=False).apply(lambda x: 1 if x else 0)
# kiam tra xem co gia tri nao khong chuyn duoc
is_null=df['dummy_panel'].isnull().any()
is_null # tra ve False tuc la tot
# Out:
# /tmp/ipykernel_526874/832094059.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dummy_panel']=df['ScreenResolution'].str.contains('ips', case=False, na=False).apply(lambda x: 1 if x else 0)
# np.False_

# %% [markdown]
# Clean truong Weight

# %% [markdown]
# Loai bo 'kg' khoi truong Weight

# %%
df.loc[:,'Weight']=df['Weight'].str.removesuffix('kg')

# %% [markdown]
# Chuyen truong Weight thanh so va generate gia tri cho cai ban ghi null

# %%
# chuyen Truong Weight thanh so neu khong chuyen dc thi thanh null
df.loc[:,'Weight']=pd.to_numeric(df['Weight'], errors='coerce')
# Kiem tra xem co ban ghi nao khong the chuyen thanh so 
print(df['Weight'].isnull().any())

# Generate gia tri cho cac ban ghi null

#Lay top 5 gia tri co tan so cao nhat
top5_Weight=df['Weight'].value_counts().nlargest(5)
prob=top5_Weight / top5_Weight.sum() # lay xac xuat tung gia tri
df.loc[:,'Weight']=df['Weight'].apply(
    lambda x: np.random.choice(top5_Weight.index,p=prob) if pd.isnull(x) else x)

print(df['Weight'].isnull().any()) # Moi thu deu on
# Out:
# True
# False

# %% [markdown]
# Ve bieu do de de quan sat truong Weight de hon

# %%
# Ve bieu do cot
plt.figure(figsize=(10,6))
plt.hist(df['Weight'], bins=20,color='skyblue', edgecolor='black')
plt.xlabel( 'Weight')
plt.ylabel('Frequency')
plt.title('Bieu do the hien phan bo cua Weight')
plt.show()

# %% [markdown]
# Ta thay truong Weigh van con mot so outlier, ta se su dung IQR de loai bo no roi se generate lai no.

# %%
Q1=df['Weight'].quantile(0.25)
Q3=df['Weight'].quantile(0.75)
IQR= Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print(lower_bound, upper_bound)

df.loc[(df['Weight']<lower_bound) | (df['Weight']>upper_bound) ,'Weight']=np.nan

#Lay top 5 gia tri co tan so cao nhat
top5_Weight=df['Weight'].value_counts().nlargest(5)
prob=top5_Weight / top5_Weight.sum() # lay xac xuat tung gia tri
# generate gia tri theo phan bo 
df.loc[:,'Weight']=df['Weight'].apply(lambda x: np.random.choice(top5_Weight.index,p=prob) if pd.isnull(x) else x)
# kiem tra con gia tri null nao khong
print(df['Weight'].isnull().any()) # Moi thu deu on
# Out:
# 0.27000000000000024 3.55
# False

# %% [markdown]
# Ve bieu do

# %%
# Ve bieu do cot
plt.figure(figsize=(10,6))
plt.hist(df['Weight'], bins=20,color='skyblue', edgecolor='black')
plt.xlabel( 'Weight')
plt.ylabel('Frequency')
plt.title('Bieu do the hien phan bo cua Weight')
plt.show()

all_value=df['Weight'].value_counts()
# Ve bieu do tron
plt.figure(figsize=(8,8))
plt.pie(all_value, labels=all_value.index, autopct='%1.1f%%', startangle=90)
plt.title('Phan bo cau weight')
plt.show()

# %% [markdown]
# Sau day la phan luu du lieu vao MongoDB

# %%
client=MongoClient('mongodb://localhost:27017/')
db=client['laptopData']
collection=db['duy']

data_dict=df.to_dict('records')

collection.insert_many(data_dict)

print('Da luu du lieu vao MongoDB')
# Out:
# Da luu du lieu vao MongoDB

# %%
sns.pairplot(df)
